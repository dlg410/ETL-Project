# %%
import pandas as pd

# %%
data_df=pd.read_csv("../../1-Extract/Raw data/Scraped Data/Inequality-Adjusted Education Index.csv")

# %%
data_df
# Out:
#      Unnamed: 0  HDI Rank                                            Country  \
# 0             1       NaN                                                NaN
# 1             2     170.0                                        Afghanistan
# 2             3      69.0                                            Albania
# 3             4      82.0                                            Algeria
# 4             5      36.0                                            Andorra
# ..          ...       ...                                                ...
# 203         204       NaN                          Least Developed Countries
# 204         205       NaN                     Small Island Developing States
# 205         206       NaN  Organization for Economic Co-operation and Dev...
# 206         207       NaN                                              World
# 207         208       NaN                                                NaN
#
# ...

# %%
data_df.drop(data_df.columns[data_df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
data_df
# Out:
#      HDI Rank                                            Country   2010  \
# 0         NaN                                                NaN    NaN
# 1       170.0                                        Afghanistan  0.226
# 2        69.0                                            Albania  0.587
# 3        82.0                                            Algeria     ..
# 4        36.0                                            Andorra     ..
# ..        ...                                                ...    ...
# 203       NaN                          Least Developed Countries  0.244
# 204       NaN                     Small Island Developing States  0.440
# 205       NaN  Organization for Economic Co-operation and Dev...  0.749
# 206       NaN                                              World  0.437
# 207       NaN                                                NaN    NaN
#
#       2011   2012   2013   2014   2015   2016   2017   2018
# ...

# %%
clean_df = data_df.dropna(0)
clean_df
# Out:
#      HDI Rank                           Country   2010   2011   2012   2013  \
# 1       170.0                       Afghanistan  0.226  0.227  0.237  0.219
# 2        69.0                           Albania  0.587  0.630  0.655  0.672
# 3        82.0                           Algeria     ..     ..     ..     ..
# 4        36.0                           Andorra     ..     ..     ..     ..
# 5       149.0                            Angola  0.294     ..  0.285  0.293
# ..        ...                               ...    ...    ...    ...    ...
# 185      73.0             Saint Kitts and Nevis     ..     ..     ..     ..
# 186     110.0                             Libya     ..     ..     ..     ..
# 187      18.0                     Liechtenstein     ..     ..     ..     ..
# 188      62.0                        Seychelles     ..     ..     ..     ..
# 189      94.0  Saint Vincent and the Grenadines     ..     ..     ..     ..
#
#       2014   2015   2016   2017   2018
# ...

# %%
del clean_df['HDI Rank']
clean_df
# Out:
#                               Country   2010   2011   2012   2013   2014  \
# 1                         Afghanistan  0.226  0.227  0.237  0.219  0.223
# 2                             Albania  0.587  0.630  0.655  0.672  0.682
# 3                             Algeria     ..     ..     ..     ..     ..
# 4                             Andorra     ..     ..     ..     ..     ..
# 5                              Angola  0.294     ..  0.285  0.293  0.301
# ..                                ...    ...    ...    ...    ...    ...
# 185             Saint Kitts and Nevis     ..     ..     ..     ..     ..
# 186                             Libya     ..     ..     ..     ..     ..
# 187                     Liechtenstein     ..     ..     ..     ..     ..
# 188                        Seychelles     ..     ..     ..     ..     ..
# 189  Saint Vincent and the Grenadines     ..     ..     ..     ..     ..
#
#       2015   2016   2017   2018
# 1    0.224  0.222  0.223  0.225
# ...

# %%
clean_df.to_csv("../Cleaned/Inequality-Adjusted Education Index.csv")
