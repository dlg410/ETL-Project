# %%
import pandas as pd

# %%
data_df=pd.read_csv("../../1-Extract/Raw data/Scraped Data/Inequality-Adjusted Life Expectancy Index.csv")

# %%
data_df
# Out:
#      Unnamed: 0 HDI Rank                                            Country  \
# 0             1      NaN                                                NaN
# 1             2      170                                        Afghanistan
# 2             3       69                                            Albania
# 3             4       82                                            Algeria
# 4             5      149                                             Angola
# ..          ...      ...                                                ...
# 205         206      NaN                          Least Developed Countries
# 206         207      NaN                     Small Island Developing States
# 207         208      NaN  Organization for Economic Co-operation and Dev...
# 208         209      NaN                                              World
# 209         210      NaN                                                NaN
#
# ...

# %%
data_df.drop(data_df.columns[data_df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
data_df
# Out:
#     HDI Rank                                            Country   2010   2011  \
# 0        NaN                                                NaN    NaN    NaN
# 1        170                                        Afghanistan  0.260  0.314
# 2         69                                            Albania  0.775  0.778
# 3         82                                            Algeria  0.694  0.726
# 4        149                                             Angola  0.252  0.301
# ..       ...                                                ...    ...    ...
# 205      NaN                          Least Developed Countries  0.386  0.421
# 206      NaN                     Small Island Developing States  0.600  0.642
# 207      NaN  Organization for Economic Co-operation and Dev...  0.855  0.861
# 208      NaN                                              World  0.612  0.634
# 209      NaN                                                NaN    NaN    NaN
#
# ...

# %%
clean_df = data_df.dropna(0)
clean_df
# Out:
#     HDI Rank                Country   2010   2011   2012   2013   2014   2015  \
# 1        170            Afghanistan  0.260  0.314  0.318  0.430  0.434  0.429
# 2         69                Albania  0.775  0.778  0.782  0.798  0.801  0.804
# 3         82                Algeria  0.694  0.726  0.729  0.713  0.716  0.702
# 4        149                 Angola  0.252  0.301  0.309  0.315  0.321  0.326
# 5         74    Antigua and Barbuda     ..     ..     ..  0.796  0.798  0.796
# ..       ...                    ...    ...    ...    ...    ...    ...    ...
# 187       98               Dominica     ..     ..     ..     ..     ..     ..
# 188       73  Saint Kitts and Nevis     ..     ..     ..     ..     ..     ..
# 189       18          Liechtenstein     ..     ..     ..     ..     ..     ..
# 190      117       Marshall Islands     ..     ..     ..     ..     ..     ..
# 191       55                  Palau     ..     ..     ..     ..     ..     ..
#
#       2016   2017   2018
# ...

# %%
del clean_df['HDI Rank']
clean_df
# Out:
#                    Country   2010   2011   2012   2013   2014   2015   2016  \
# 1              Afghanistan  0.260  0.314  0.318  0.430  0.434  0.429  0.482
# 2                  Albania  0.775  0.778  0.782  0.798  0.801  0.804  0.813
# 3                  Algeria  0.694  0.726  0.729  0.713  0.716  0.702  0.735
# 4                   Angola  0.252  0.301  0.309  0.315  0.321  0.326  0.406
# 5      Antigua and Barbuda     ..     ..     ..  0.796  0.798  0.796  0.806
# ..                     ...    ...    ...    ...    ...    ...    ...    ...
# 187               Dominica     ..     ..     ..     ..     ..     ..     ..
# 188  Saint Kitts and Nevis     ..     ..     ..     ..     ..     ..     ..
# 189          Liechtenstein     ..     ..     ..     ..     ..     ..     ..
# 190       Marshall Islands     ..     ..     ..     ..     ..     ..     ..
# 191                  Palau     ..     ..     ..     ..     ..     ..     ..
#
#       2017   2018
# 1    0.486  0.491
# ...

# %%
clean_df.to_csv("../Cleaned/Inequality-Adjusted Life Expectancy Index.csv")
