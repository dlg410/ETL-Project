# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:password@localhost/HDI vs WHR')
conn = engine.connect()

# %%
data_df=pd.read_csv("../../1-Extract/Raw data/Scraped Data/Expected Years of Schooling.csv")

# %%
data_df
# Out:
#      Unnamed: 0 HDI Rank      Country  1990  Unnamed: 4  1991  Unnamed: 6  \
# 0             1      NaN          NaN   NaN         NaN   NaN         NaN
# 1             2      170  Afghanistan   2.6         NaN   2.9         NaN
# 2             3       69      Albania  11.6         NaN  11.8         NaN
# 3             4       82      Algeria   9.6         NaN   9.7         NaN
# 4             5       36      Andorra  10.8         NaN  10.8         NaN
# ..          ...      ...          ...   ...         ...   ...         ...
# 215         216      NaN          NaN   NaN         NaN   NaN         NaN
# 216         217      NaN          NaN   NaN         NaN   NaN         NaN
# 217         218      NaN          NaN   NaN         NaN   NaN         NaN
# 218         219      NaN          NaN   NaN         NaN   NaN         NaN
# 219         220      NaN          NaN   NaN         NaN   NaN         NaN
#
#      1992  Unnamed: 8  1993  ...  2014 Unnamed: 52  2015 Unnamed: 54  2016  \
# ...

# %%
data_df.drop(data_df.columns[data_df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
data_df
# Out:
#     HDI Rank      Country  1990  1991  1992  1993  1994  1995  1996  1997  \
# 0        NaN          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1        170  Afghanistan   2.6   2.9   3.2   3.6   3.9   4.2   4.6   4.9
# 2         69      Albania  11.6  11.8  10.7  10.2  10.1  10.2  10.3  10.6
# 3         82      Algeria   9.6   9.7   9.8   9.8   9.9   9.8  10.0  10.3
# 4         36      Andorra  10.8  10.8  10.8  10.8  10.8  10.8  10.8  10.8
# ..       ...          ...   ...   ...   ...   ...   ...   ...   ...   ...
# 215      NaN          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 216      NaN          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 217      NaN          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 218      NaN          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 219      NaN          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      ...  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# ...

# %%
clean_df = (data_df.drop(data_df.iloc[:, 2:22], axis = 1).dropna(0))
clean_df
# Out:
#     HDI Rank                             Country  2010  2011  2012  2013  \
# 1        170                         Afghanistan   9.5   9.5  10.0  10.2
# 2         69                             Albania  13.1  13.8  14.7  15.4
# 3         82                             Algeria  14.0  14.3  13.9  14.3
# 4         36                             Andorra  11.7  11.7  13.5  13.1
# 5        149                              Angola   8.6   9.5   9.9  10.3
# ..       ...                                 ...   ...   ...   ...   ...
# 189       96  Venezuela (Bolivarian Republic of)  13.6  13.7  13.8  14.2
# 190      118                            Viet Nam  12.0  12.5  12.6  12.6
# 191      177                               Yemen   8.6   9.0   8.5   8.8
# 192      143                              Zambia  11.0  10.9  10.9  11.0
# 193      150                            Zimbabwe  10.1  10.2  10.3  10.2
#
#      2014  2015  2016  2017  2018
# 1    10.3  10.2  10.3  10.1  10.1
# ...

# %%
del clean_df['HDI Rank']
clean_df
# Out:
#                                 Country  2010  2011  2012  2013  2014  2015  \
# 1                           Afghanistan   9.5   9.5  10.0  10.2  10.3  10.2
# 2                               Albania  13.1  13.8  14.7  15.4  15.8  15.7
# 3                               Algeria  14.0  14.3  13.9  14.3  14.4  14.4
# 4                               Andorra  11.7  11.7  13.5  13.1  13.5  13.1
# 5                                Angola   8.6   9.5   9.9  10.3  10.7  11.0
# ..                                  ...   ...   ...   ...   ...   ...   ...
# 189  Venezuela (Bolivarian Republic of)  13.6  13.7  13.8  14.2  14.1  14.0
# 190                            Viet Nam  12.0  12.5  12.6  12.6  12.7  12.7
# 191                               Yemen   8.6   9.0   8.5   8.8   8.7   8.7
# 192                              Zambia  11.0  10.9  10.9  11.0  10.9  10.9
# 193                            Zimbabwe  10.1  10.2  10.3  10.2  10.3  10.3
#
#      2016  2017  2018
# 1    10.3  10.1  10.1
# ...

# %%
clean_df.to_csv("../Cleaned/Expected Years of Schooling.csv")

# %%
clean_df.to_sql(
    name='Expected Years of Schooling',
    con=engine,
    index=False
)

# %%
engine = create_engine('sqlite:///Indicators.db', echo=True)
sqlite_connection = engine.connect()
# Out:
# 2020-08-09 18:11:05,165 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-08-09 18:11:05,168 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-09 18:11:05,170 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-08-09 18:11:05,171 INFO sqlalchemy.engine.base.Engine ()

# %%
sqlite_table = "Expected Years of Schooling"
clean_df.to_sql(sqlite_table, sqlite_connection, if_exists='fail')
# Out:
# 2020-08-09 18:11:05,182 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Expected Years of Schooling")
# 2020-08-09 18:11:05,186 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-09 18:11:05,188 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("Expected Years of Schooling")
# 2020-08-09 18:11:05,194 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-09 18:11:05,199 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "Expected Years of Schooling" (
# 	"index" BIGINT,
# 	"Country" TEXT,
# 	"2010" TEXT,
# 	"2011" TEXT,
# 	"2012" TEXT,
# 	"2013" TEXT,
# 	"2014" TEXT,
# 	"2015" TEXT,
# 	"2016" TEXT,
# 	"2017" TEXT,
# 	"2018" TEXT
# )
#
#
# 2020-08-09 18:11:05,201 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-09 18:11:05,206 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-08-09 18:11:05,207 INFO sqlalchemy.engine.base.Engine CREATE INDEX "ix_Expected Years of Schooling_index" ON "Expected Years of Schooling" ("index")
# ...

# %%
sqlite_connection.close()
