# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:password@localhost/HDI vs WHR')
conn = engine.connect()

# %%
data_df=pd.read_csv("../../1-Extract/Raw data/Scraped Data/Gross Domestic Product (GDP) Per Capita.csv")

# %%
data_df
# Out:
#      Unnamed: 0 HDI Rank      Country   1990  Unnamed: 4  1995  Unnamed: 6  \
# 0             1      NaN          NaN    NaN         NaN   NaN         NaN
# 1             2      170  Afghanistan     ..         NaN    ..         NaN
# 2             3       69      Albania   4458         NaN  4130         NaN
# 3             4       82      Algeria  10298         NaN  9343         NaN
# 4             5      149       Angola   4761         NaN  3408         NaN
# ..          ...      ...          ...    ...         ...   ...         ...
# 209         210      NaN        World   8958         NaN  9242         NaN
# 210         211      NaN          NaN    NaN         NaN   NaN         NaN
# 211         212      NaN          NaN    NaN         NaN   NaN         NaN
# 212         213      NaN          NaN    NaN         NaN   NaN         NaN
# 213         214      NaN          NaN    NaN         NaN   NaN         NaN
#
# ...

# %%
data_df.drop(data_df.columns[data_df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
data_df
# Out:
#     HDI Rank      Country   1990  1995   2000   2005   2010   2011   2012  \
# 0        NaN          NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 1        170  Afghanistan     ..    ..     ..   1099   1672   1627   1773
# 2         69      Albania   4458  4130   5443   7426   9928  10208  10370
# 3         82      Algeria  10298  9343  10258  12374  12921  13046  13226
# 4        149       Angola   4761  3408   3892   5113   6360   6346   6645
# ..       ...          ...    ...   ...    ...    ...    ...    ...    ...
# 209      NaN        World   8958  9242  10379  11712  13185  13559  13859
# 210      NaN          NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 211      NaN          NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 212      NaN          NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 213      NaN          NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN
#
#       2013   2014   2015   2016   2017   2018
# ...

# %%
clean_df = (data_df.drop(data_df.iloc[:, 2:6], axis = 1).dropna(0))
clean_df
# Out:
#     HDI Rank               Country   2010   2011   2012   2013   2014   2015  \
# 1        170           Afghanistan   1672   1627   1773   1808   1796   1767
# 2         69               Albania   9928  10208  10370  10493  10701  10971
# 3         82               Algeria  12921  13046  13226  13323  13549  13774
# 4        149                Angola   6360   6346   6645   6731   6813   6645
# 5         74   Antigua and Barbuda  20660  19953  20389  20121  20821  21426
# ..       ...                   ...    ...    ...    ...    ...    ...    ...
# 188      150              Zimbabwe   1928   2168   2487   2492   2506   2509
# 189       36               Andorra     ..     ..     ..     ..     ..     ..
# 190       72                  Cuba     ..     ..     ..     ..     ..     ..
# 191       18         Liechtenstein     ..     ..     ..     ..     ..     ..
# 192      154  Syrian Arab Republic     ..     ..     ..     ..     ..     ..
#
#       2016   2017   2018
# ...

# %%
del clean_df['HDI Rank']
clean_df
# Out:
#                   Country   2010   2011   2012   2013   2014   2015   2016  \
# 1             Afghanistan   1672   1627   1773   1808   1796   1767   1757
# 2                 Albania   9928  10208  10370  10493  10701  10971  11357
# 3                 Algeria  12921  13046  13226  13323  13549  13774  13940
# 4                  Angola   6360   6346   6645   6731   6813   6645   6258
# 5     Antigua and Barbuda  20660  19953  20389  20121  20821  21426  22394
# ..                    ...    ...    ...    ...    ...    ...    ...    ...
# 188              Zimbabwe   1928   2168   2487   2492   2506   2509   2489
# 189               Andorra     ..     ..     ..     ..     ..     ..     ..
# 190                  Cuba     ..     ..     ..     ..     ..     ..     ..
# 191         Liechtenstein     ..     ..     ..     ..     ..     ..     ..
# 192  Syrian Arab Republic     ..     ..     ..     ..     ..     ..     ..
#
#       2017   2018
# 1     1758   1735
# 2    11803  12306
# ...

# %%
clean_df.to_csv("../Cleaned/Gross Domestic Product (GDP) Per Capita.csv")

# %%
clean_df.to_sql(
    name='Gross Domestic Product (GDP) Per Capita',
    con=engine,
    index=False
)
