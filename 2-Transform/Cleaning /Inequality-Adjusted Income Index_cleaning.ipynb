# %%
import pandas as pd

# %%
data_df=pd.read_csv("../../1-Extract/Raw data/Scraped Data/Inequality-Adjusted Income Index.csv")

# %%
data_df
# Out:
#      Unnamed: 0 HDI Rank                                            Country  \
# 0             1      NaN                                                NaN
# 1             2      170                                        Afghanistan
# 2             3       69                                            Albania
# 3             4       82                                            Algeria
# 4             5      149                                             Angola
# ..          ...      ...                                                ...
# 205         206      NaN                          Least Developed Countries
# 206         207      NaN                     Small Island Developing States
# 207         208      NaN  Organization for Economic Co-operation and Dev...
# 208         209      NaN                                              World
# 209         210      NaN                                                NaN
#
# ...

# %%
data_df.drop(data_df.columns[data_df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
data_df
# Out:
#     HDI Rank                                            Country   2010   2011  \
# 0        NaN                                                NaN    NaN    NaN
# 1        170                                        Afghanistan     ..     ..
# 2         69                                            Albania  0.593  0.571
# 3         82                                            Algeria     ..     ..
# 4        149                                             Angola  0.390  0.307
# ..       ...                                                ...    ...    ...
# 205      NaN                          Least Developed Countries  0.358  0.349
# 206      NaN                     Small Island Developing States  0.472  0.476
# 207      NaN  Organization for Economic Co-operation and Dev...  0.700  0.684
# 208      NaN                                              World  0.570  0.567
# 209      NaN                                                NaN    NaN    NaN
#
# ...

# %%
clean_df = data_df.dropna(0)
clean_df
# Out:
#     HDI Rank                           Country   2010   2011   2012   2013  \
# 1        170                       Afghanistan     ..     ..     ..  0.391
# 2         69                           Albania  0.593  0.571  0.572  0.576
# 3         82                           Algeria     ..     ..     ..     ..
# 4        149                            Angola  0.390  0.307  0.311  0.313
# 5         48                         Argentina  0.516  0.521  0.520  0.571
# ..       ...                               ...    ...    ...    ...    ...
# 187       41                             Qatar     ..     ..     ..     ..
# 188       36                      Saudi Arabia     ..     ..     ..     ..
# 189      105                             Tonga     ..     ..     ..     ..
# 190       94  Saint Vincent and the Grenadines     ..     ..     ..     ..
# 191      111                             Samoa     ..     ..     ..     ..
#
#       2014   2015   2016   2017   2018
# ...

# %%
del clean_df['HDI Rank']
clean_df
# Out:
#                               Country   2010   2011   2012   2013   2014  \
# 1                         Afghanistan     ..     ..     ..  0.391  0.389
# 2                             Albania  0.593  0.571  0.572  0.576  0.578
# 3                             Algeria     ..     ..     ..     ..     ..
# 4                              Angola  0.390  0.307  0.311  0.313  0.448
# 5                           Argentina  0.516  0.521  0.520  0.571  0.582
# ..                                ...    ...    ...    ...    ...    ...
# 187                             Qatar     ..     ..     ..     ..     ..
# 188                      Saudi Arabia     ..     ..     ..     ..     ..
# 189                             Tonga     ..     ..     ..     ..     ..
# 190  Saint Vincent and the Grenadines     ..     ..     ..     ..     ..
# 191                             Samoa     ..     ..     ..     ..     ..
#
#       2015   2016   2017   2018
# 1    0.388  0.387  0.387     ..
# ...

# %%
clean_df.to_csv("../Cleaned/Inequality-Adjusted Income Index.csv")
