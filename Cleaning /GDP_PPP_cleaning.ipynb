# %%
import pandas as pd

# %%
data_df=pd.read_csv("GDP_PPP/GDP_PCAP_PPP.csv")

# %%
data_df
# Out:
#      Country Name Country Code                                 Indicator Name  \
# 0           Aruba          ABW  GDP per capita, PPP (current international $)
# 1     Afghanistan          AFG  GDP per capita, PPP (current international $)
# 2          Angola          AGO  GDP per capita, PPP (current international $)
# 3         Albania          ALB  GDP per capita, PPP (current international $)
# 4         Andorra          AND  GDP per capita, PPP (current international $)
# ..            ...          ...                                            ...
# 259        Kosovo          XKX  GDP per capita, PPP (current international $)
# 260   Yemen, Rep.          YEM  GDP per capita, PPP (current international $)
# 261  South Africa          ZAF  GDP per capita, PPP (current international $)
# 262        Zambia          ZMB  GDP per capita, PPP (current international $)
# 263      Zimbabwe          ZWE  GDP per capita, PPP (current international $)
#
# ...

# %%
clean_df = data_df.drop(data_df.iloc[:, 1:54], axis = 1)
clean_df
# Out:
#      Country Name          2010          2011          2012          2013  \
# 0           Aruba  32624.209090  34326.144820  33569.186500  36477.779390
# 1     Afghanistan   1710.575645   1699.487997   1914.774351   2015.514962
# 2          Angola   6587.986901   6710.750346   7412.965263   7682.477158
# 3         Albania   9635.183332  10207.769440  10526.295020  10570.977180
# 4         Andorra           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259        Kosovo   7782.947105   8222.225939   8477.469769   8805.379754
# 260   Yemen, Rep.   4162.088451   3607.090263   3491.204325   3688.519849
# 261  South Africa  11721.555060  12172.314740  12057.268710  12450.497500
# 262        Zambia   3178.872797   3323.939045   3422.626326   3578.853190
# 263      Zimbabwe   1830.828054   2101.825192   2375.930267   2560.777487
#
#              2014          2015          2016          2017          2018  \
# ...

# %%
clean_df.fillna(0)
# Out:
#      Country Name          2010          2011          2012          2013  \
# 0           Aruba  32624.209090  34326.144820  33569.186500  36477.779390
# 1     Afghanistan   1710.575645   1699.487997   1914.774351   2015.514962
# 2          Angola   6587.986901   6710.750346   7412.965263   7682.477158
# 3         Albania   9635.183332  10207.769440  10526.295020  10570.977180
# 4         Andorra      0.000000      0.000000      0.000000      0.000000
# ..            ...           ...           ...           ...           ...
# 259        Kosovo   7782.947105   8222.225939   8477.469769   8805.379754
# 260   Yemen, Rep.   4162.088451   3607.090263   3491.204325   3688.519849
# 261  South Africa  11721.555060  12172.314740  12057.268710  12450.497500
# 262        Zambia   3178.872797   3323.939045   3422.626326   3578.853190
# 263      Zimbabwe   1830.828054   2101.825192   2375.930267   2560.777487
#
#              2014          2015          2016          2017          2018  \
# ...

# %%
del clean_df['2019']
clean_df
# Out:
#      Country Name          2010          2011          2012          2013  \
# 0           Aruba  32624.209090  34326.144820  33569.186500  36477.779390
# 1     Afghanistan   1710.575645   1699.487997   1914.774351   2015.514962
# 2          Angola   6587.986901   6710.750346   7412.965263   7682.477158
# 3         Albania   9635.183332  10207.769440  10526.295020  10570.977180
# 4         Andorra           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259        Kosovo   7782.947105   8222.225939   8477.469769   8805.379754
# 260   Yemen, Rep.   4162.088451   3607.090263   3491.204325   3688.519849
# 261  South Africa  11721.555060  12172.314740  12057.268710  12450.497500
# 262        Zambia   3178.872797   3323.939045   3422.626326   3578.853190
# 263      Zimbabwe   1830.828054   2101.825192   2375.930267   2560.777487
#
#              2014          2015          2016          2017          2018
# ...

# %%
clean_df.fillna(0)
# Out:
#      Country Name          2010          2011          2012          2013  \
# 0           Aruba  32624.209090  34326.144820  33569.186500  36477.779390
# 1     Afghanistan   1710.575645   1699.487997   1914.774351   2015.514962
# 2          Angola   6587.986901   6710.750346   7412.965263   7682.477158
# 3         Albania   9635.183332  10207.769440  10526.295020  10570.977180
# 4         Andorra      0.000000      0.000000      0.000000      0.000000
# ..            ...           ...           ...           ...           ...
# 259        Kosovo   7782.947105   8222.225939   8477.469769   8805.379754
# 260   Yemen, Rep.   4162.088451   3607.090263   3491.204325   3688.519849
# 261  South Africa  11721.555060  12172.314740  12057.268710  12450.497500
# 262        Zambia   3178.872797   3323.939045   3422.626326   3578.853190
# 263      Zimbabwe   1830.828054   2101.825192   2375.930267   2560.777487
#
#              2014          2015          2016          2017          2018
# ...

# %%
clean_df.to_csv("./Clean/GDP_PPP.csv")
