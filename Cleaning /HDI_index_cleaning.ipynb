# %%
import pandas as pd

# %%
data_df=pd.read_csv("Human Development Index (HDI).csv")

# %%
data_df
# Out:
#     HDI Rank (2018)                                            Country   1990  \
# 0               170                                        Afghanistan  0.298
# 1                69                                            Albania  0.644
# 2                82                                            Algeria  0.578
# 3                36                                            Andorra     ..
# 4               149                                             Angola     ..
# ..              ...                                                ...    ...
# 207                                                 Sub-Saharan Africa  0.402
# 208                                          Least Developed Countries   0.35
# 209                                     Small Island Developing States  0.595
# 210                  Organization for Economic Co-operation and Dev...  0.785
# 211                                                              World  0.598
#
# ...

# %%
# data_df.drop(data_df.columns[data_df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
# data_df

# %%
# data_df.drop(data_df.iloc[:, 1:54], axis = 1)

# %%
clean_df = data_df.drop(data_df.iloc[:, 2:22], axis = 1)
clean_df
# Out:
#     HDI Rank (2018)                                            Country   2010  \
# 0               170                                        Afghanistan  0.464
# 1                69                                            Albania   0.74
# 2                82                                            Algeria   0.73
# 3                36                                            Andorra  0.828
# 4               149                                             Angola   0.51
# ..              ...                                                ...    ...
# 207                                                 Sub-Saharan Africa  0.498
# 208                                          Least Developed Countries  0.485
# 209                                     Small Island Developing States  0.702
# 210                  Organization for Economic Co-operation and Dev...  0.873
# 211                                                              World  0.697
#
# ...

# %%
clean_df.fillna(0)
# Out:
#     HDI Rank (2018)                                            Country   2010  \
# 0               170                                        Afghanistan  0.464
# 1                69                                            Albania   0.74
# 2                82                                            Algeria   0.73
# 3                36                                            Andorra  0.828
# 4               149                                             Angola   0.51
# ..              ...                                                ...    ...
# 207                                                 Sub-Saharan Africa  0.498
# 208                                          Least Developed Countries  0.485
# 209                                     Small Island Developing States  0.702
# 210                  Organization for Economic Co-operation and Dev...  0.873
# 211                                                              World  0.697
#
# ...

# %%
del clean_df['HDI Rank (2018)']
clean_df
# Out:
#                                                Country   2010   2011   2012  \
# 0                                          Afghanistan  0.464  0.465  0.479
# 1                                              Albania   0.74  0.759  0.771
# 2                                              Algeria   0.73  0.738  0.737
# 3                                              Andorra  0.828  0.827  0.849
# 4                                               Angola   0.51  0.525  0.537
# ..                                                 ...    ...    ...    ...
# 207                                 Sub-Saharan Africa  0.498  0.505  0.512
# 208                          Least Developed Countries  0.485  0.493  0.499
# 209                     Small Island Developing States  0.702  0.706  0.704
# 210  Organization for Economic Co-operation and Dev...  0.873  0.877  0.879
# 211                                              World  0.697  0.703  0.708
#
#       2013   2014   2015   2016   2017   2018
# ...

# %%
clean_df.to_csv("./Clean/Human Development Index.csv")
