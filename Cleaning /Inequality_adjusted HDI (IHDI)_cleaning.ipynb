# %%
import pandas as pd

# %%
data_df=pd.read_csv("Inequality-adjusted HDI (IHDI).csv")

# %%
data_df
# Out:
#     HDI Rank (2018)                                            Country   2010  \
# 0               170                                        Afghanistan     ..
# 1                69                                            Albania  0.646
# 2                82                                            Algeria     ..
# 3               149                                             Angola  0.307
# 4                48                                          Argentina  0.656
# ..              ...                                                ...    ...
# 201                                                 Sub-Saharan Africa  0.323
# 202                                          Least Developed Countries  0.323
# 203                                     Small Island Developing States  0.499
# 204                  Organization for Economic Co-operation and Dev...  0.765
# 205                                                              World  0.534
#
# ...

# %%
data_df.drop(data_df.columns[data_df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
data_df
# Out:
#     HDI Rank (2018)                                            Country   2010  \
# 0               170                                        Afghanistan     ..
# 1                69                                            Albania  0.646
# 2                82                                            Algeria     ..
# 3               149                                             Angola  0.307
# 4                48                                          Argentina  0.656
# ..              ...                                                ...    ...
# 201                                                 Sub-Saharan Africa  0.323
# 202                                          Least Developed Countries  0.323
# 203                                     Small Island Developing States  0.499
# 204                  Organization for Economic Co-operation and Dev...  0.765
# 205                                                              World  0.534
#
# ...

# %%
data_df.fillna(0)
# Out:
#     HDI Rank (2018)                                            Country   2010  \
# 0               170                                        Afghanistan     ..
# 1                69                                            Albania  0.646
# 2                82                                            Algeria     ..
# 3               149                                             Angola  0.307
# 4                48                                          Argentina  0.656
# ..              ...                                                ...    ...
# 201                                                 Sub-Saharan Africa  0.323
# 202                                          Least Developed Countries  0.323
# 203                                     Small Island Developing States  0.499
# 204                  Organization for Economic Co-operation and Dev...  0.765
# 205                                                              World  0.534
#
# ...

# %%
del data_df['HDI Rank (2018)']
data_df
# Out:
#                                                Country   2010   2011   2012  \
# 0                                          Afghanistan     ..     ..     ..
# 1                                              Albania  0.646  0.654  0.664
# 2                                              Algeria     ..     ..     ..
# 3                                               Angola  0.307     ..  0.301
# 4                                            Argentina  0.656  0.662  0.662
# ..                                                 ...    ...    ...    ...
# 201                                 Sub-Saharan Africa  0.323  0.331  0.333
# 202                          Least Developed Countries  0.323  0.333  0.337
# 203                     Small Island Developing States  0.499  0.509  0.502
# 204  Organization for Economic Co-operation and Dev...  0.765  0.762  0.769
# 205                                              World  0.534  0.542  0.543
#
#       2013   2014   2015   2016   2017   2018
# ...

# %%
data_df.to_csv("./Clean/Inequality-adjusted HDI (IHDI).csv")
