# %%
import pandas as pd

# %%
data_df=pd.read_csv("average-schooling-vs-expected-schooling.csv")

# %%
data_df
# Out:
#             Entity Code  Year  Average years of schooling (years)  \
# 0      Afghanistan  AFG  1870                                0.01
# 1      Afghanistan  AFG  1875                                0.01
# 2      Afghanistan  AFG  1880                                0.01
# 3      Afghanistan  AFG  1885                                0.01
# 4      Afghanistan  AFG  1890                                0.01
# ...            ...  ...   ...                                 ...
# 17291     Zimbabwe  ZWE  1984                                 NaN
# 17292     Zimbabwe  ZWE  1986                                 NaN
# 17293     Zimbabwe  ZWE  1987                                 NaN
# 17294     Zimbabwe  ZWE  1988                                 NaN
# 17295     Zimbabwe  ZWE  1989                                 NaN
#
#        Expected Years of Schooling (years)  Population, total
# 0                                      NaN                NaN
# ...

# %%
del data_df['Code']
data_df
# Out:
#             Entity  Year  Average years of schooling (years)  \
# 0      Afghanistan  1870                                0.01
# 1      Afghanistan  1875                                0.01
# 2      Afghanistan  1880                                0.01
# 3      Afghanistan  1885                                0.01
# 4      Afghanistan  1890                                0.01
# ...            ...   ...                                 ...
# 17291     Zimbabwe  1984                                 NaN
# 17292     Zimbabwe  1986                                 NaN
# 17293     Zimbabwe  1987                                 NaN
# 17294     Zimbabwe  1988                                 NaN
# 17295     Zimbabwe  1989                                 NaN
#
#        Expected Years of Schooling (years)  Population, total
# 0                                      NaN                NaN
# 1                                      NaN                NaN
# ...

# %%
del data_df['Population, total']
data_df
# Out:
#             Entity  Year  Average years of schooling (years)  \
# 0      Afghanistan  1870                                0.01
# 1      Afghanistan  1875                                0.01
# 2      Afghanistan  1880                                0.01
# 3      Afghanistan  1885                                0.01
# 4      Afghanistan  1890                                0.01
# ...            ...   ...                                 ...
# 17291     Zimbabwe  1984                                 NaN
# 17292     Zimbabwe  1986                                 NaN
# 17293     Zimbabwe  1987                                 NaN
# 17294     Zimbabwe  1988                                 NaN
# 17295     Zimbabwe  1989                                 NaN
#
#        Expected Years of Schooling (years)
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# ...

# %%
clean_df = data_df.fillna(0)

# %%
clean10_df = clean_df.loc[clean_df['Year'] == 2010]

# %%
clean10_df = clean_df.loc[clean_df['Year'] == 2010]

# %%
clean11_df = clean_df.loc[clean_df['Year'] == 2011]

# %%
clean12_df = clean_df.loc[clean_df['Year'] == 2012]

# %%
clean13_df = clean_df.loc[clean_df['Year'] == 2013]

# %%
clean14_df = clean_df.loc[clean_df['Year'] == 2014]

# %%
clean15_df = clean_df.loc[clean_df['Year'] == 2015]

# %%
clean16_df = clean_df.loc[clean_df['Year'] == 2016]

# %%
clean17_df = clean_df.loc[clean_df['Year'] == 2017]

# %%
clean18_df = clean_df.loc[clean_df['Year'] == 2018]

# %%
clean10_df.to_csv("./Clean/Average schooling Vs Expected schooling 2010.csv", index = False)

# %%
clean11_df.to_csv("./Clean/Average schooling Vs Expected schooling 2011.csv", index = False)

# %%
clean12_df.to_csv("./Clean/Average schooling Vs Expected schooling 2012.csv", index = False)

# %%
clean13_df.to_csv("./Clean/Average schooling Vs Expected schooling 2013.csv", index = False)

# %%
clean14_df.to_csv("./Clean/Average schooling Vs Expected schooling 2014.csv", index = False)

# %%
clean15_df.to_csv("./Clean/Average schooling Vs Expected schooling 2015.csv", index = False)

# %%
clean16_df.to_csv("./Clean/Average schooling Vs Expected schooling 2016.csv", index = False)

# %%
clean17_df.to_csv("./Clean/Average schooling Vs Expected schooling 2017.csv", index = False)

# %%
clean18_df.to_csv("./Clean/Average schooling Vs Expected schooling 2018.csv", index = False)
