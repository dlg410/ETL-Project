# %%
import pandas as pd

# %%
data_df=pd.read_csv("world-happiness-report-2005-2018.csv", sep = ';')

# %%
data_df
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# ...           ...   ...          ...                 ...             ...
# 1699     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
clean_df = data_df.drop(data_df.iloc[:, 19:26], axis = 1)
clean_df
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# ...           ...   ...          ...                 ...             ...
# 1699     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
clean_df.fillna(0)
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# ...           ...   ...          ...                 ...             ...
# 1699     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
clean10_df = clean_df.loc[clean_df['Year'] == 2010]

# %%
clean11_df = clean_df.loc[clean_df['Year'] == 2011]

# %%
clean12_df = clean_df.loc[clean_df['Year'] == 2012]

# %%
clean13_df = clean_df.loc[clean_df['Year'] == 2013]

# %%
clean14_df = clean_df.loc[clean_df['Year'] == 2014]

# %%
clean15_df = clean_df.loc[clean_df['Year'] == 2015]

# %%
clean16_df = clean_df.loc[clean_df['Year'] == 2016]

# %%
clean17_df = clean_df.loc[clean_df['Year'] == 2017]

# %%
clean18_df = clean_df.loc[clean_df['Year'] == 2018]

# %%
clean10_df.to_csv("./Clean/World Happiness Report 2010.csv", index = False)

# %%
clean11_df.to_csv("./Clean/World Happiness Report 2011.csv", index = False)

# %%
clean12_df.to_csv("./Clean/World Happiness Report 2012.csv", index = False)

# %%
clean13_df.to_csv("./Clean/World Happiness Report 2013.csv", index = False)

# %%
clean14_df.to_csv("./Clean/World Happiness Report 2014.csv", index = False)

# %%
clean15_df.to_csv("./Clean/World Happiness Report 2015.csv", index = False)

# %%
clean16_df.to_csv("./Clean/World Happiness Report 2016.csv", index = False)

# %%
clean17_df.to_csv("./Clean/World Happiness Report 2017.csv", index = False)

# %%
clean18_df.to_csv("./Clean/World Happiness Report 2018.csv", index = False)
